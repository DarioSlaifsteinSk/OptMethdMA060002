# %% [markdown]
# # Optimization Methods MA060002
# ## Homework 2
# By: Darío Slaifstein, PhD-2.

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.patches import Polygon
from matplotlib.lines import Line2D
from matplotlib import cm

from numpy import linalg as LNG
from scipy.optimize import minimize_scalar
from scipy.optimize import minimize
from scipy import optimize

# %% [markdown]
# ### 1.
# _Find minimum (i.e. both point $x^∗$ and function value $f^∗ = f(x^∗)$) of function with
# respect to parameters $a$, $b$, $c$ :
# \begin{equation}
# f(x) = a.x^2 + b.x + c
# \end{equation}_
#
# To find the minimum value of $f(x)$ we need to assure the optimally conditions:
# \begin{equation}
#  \nabla f(x^*) = 0 \rightarrow f'(x^*)=0
# \end{equation}
# \begin{equation}
#  det(\nabla^{2} f(x^*)) > 0 \rightarrow f''(x^*)=0
# \end{equation}
#
# Hence the first derivative $f'(x)$ is:
# \begin{equation}
# f'(x^*) = 2.a.x^* + b \rightarrow 2.a.x+b=0
# \end{equation}
# \begin{equation}
#  x^*=-b/2a
# \end{equation}
#
# for the second derivative $f''(x)$
# \begin{equation}
# f''(x^*) = 2.a >0 \rightarrow a>0
# \end{equation}
#
# The minimum function value $f^*$ is:
# \begin{equation}
# f(x^*) = a.(\frac{-b}{2a})^2 + b.\frac{-b}{2a} + c
# \end{equation}
# \begin{equation}
# f(x^*) = \frac{b^2}{4a} -\frac{b^2}{2a} + c
# \end{equation}
# \begin{equation}
# f(x^*) = \frac{-b^2}{4a}+ c
# \end{equation}
#
# ### 2.
# The gradient $\nabla h(x): \mathbb{R}^m \rightarrow \mathbb{R}^k$ due to the composition rule. Because:
# \begin{equation}
# \nabla h = A^T.\nabla f(A.x)
# \end{equation}
#
# Since $\nabla f(A.x): \mathbb{R}^m \rightarrow \mathbb{R}^m$ and $A^T\ \in \mathbb{R}^{k\ x\ m}$ their product has to be a function $\mathbb{R}^m \rightarrow \mathbb{R}^k$.
#
# ### 3.
# The gradient of $f$ is:
# \begin{equation}
# \nabla f = 2.(x.c^T).c
# \end{equation}
# And the Hessian is
# \begin{equation}
# \nabla^2 f = 2.c.c^T
# \end{equation}
#
# ### 4.
# \begin{equation}
# \nabla f = A^T.\nabla_y g(Ax+b)
# \end{equation}
# \begin{equation}
# \nabla^2_x f = A^{T}.\nabla^2_y g(Ax+b).A
# \end{equation}
#
# ### 5.
# Given that $A\succ 0 \in \mathbb{R}^{n \times n}$ and $x,\ b,\ d \in \mathbb{R}^n$ we need to find the optimal $\gamma^*$ so that:
# \begin{equation}
# f(\gamma)=(A(x+\gamma d),x+\gamma d)+(b, x+\gamma d) \rightarrow \min_{f \in \mathbb{R}}
# \end{equation}
# The optimal-step size method can be summed up as:
# \begin{equation}
# x^{k+1}=x^k - \gamma.\nabla f^k
# \end{equation}
# from our initial $f(\gamma)$ we can assume an $f(x)$ as:
# \begin{equation}
# f(x)=(Ax,x)+(b,x)
# \end{equation}
# \begin{equation}
# f(x)=A^T x^T x+b^T x
# \end{equation}
# the gradient of this function is:
# \begin{equation}
# \nabla f(x)= g =2A^T x+ b
# \end{equation}
# From now on, just for the sake of clarity, we will explicitly write the superscripts $k$ indicating the number of the iteration.
# Now, to find $\gamma^*$ we need to find the optimal $f(x^{k+1})$ with respect to our step-size. Hence:
# \begin{equation}
# 0 = \frac{\partial f^{k+1}}{\partial \gamma}=\frac{\partial f(x^{k+1})}{\partial \gamma}
# \end{equation}
# \begin{equation}
# 0 = \frac{\partial f(x^k - \gamma^* g^k)}{\partial \gamma}
# \end{equation}
# \begin{equation}
# 0 = \frac{\partial f(x^k - \gamma^* (2A^T x^k+ b))}{\partial \gamma}
# \end{equation}
# \begin{equation}
# \frac{\partial}{\partial \gamma}(f(x^k - \gamma^* g^k)) = \frac{\partial}{\partial \gamma}(A^T.(x^k - \gamma^* g^k)^T.(x^k - \gamma^* g^k)+b^T.(x^k - \gamma^* g^k))
# \end{equation}
# \begin{equation}
# \frac{\partial}{\partial \gamma}(A^T.(x^T.x-x^T.\gamma^* g^k -\gamma^* g^{k^T}.x+\gamma^2.g^{k^T}.g^k)+b^T.x^k - \gamma^* b^T g^k))=0
# \end{equation}
#
# \begin{equation}
# \frac{\partial}{\partial \gamma}(A^T.((x^k,x^k)-\gamma^* (x^k,g^k) -\gamma^* (g^k,x)+\gamma^2.(g^k,g^k))+(b,x^k) - \gamma^* (b,g^k))=0
# \end{equation}
#
# \begin{equation}
# \frac{\partial}{\partial \gamma}(A^T.((x^k,x^k)-2\gamma^* (x^k,g^k)+\gamma^2.(g^k,g^k))+(b,x^k) - \gamma^* (b,g^k))=0
# \end{equation}
# \begin{equation}
# -2.A^T. (x^k,g^k)+\gamma.2.A^T.(g^k,g^k) - (b,g^k) = 0
# \end{equation}
# \begin{equation}
# \gamma.2.A^T.(g^k,g^k)  = +2.A^T. (x^k,g^k) + (b,g^k)
# \end{equation}
#
#
# ### 6.
# The specified $f(x)$ can also be expressed as:
#
# \begin{equation}
# f(x)=\max{0,x^2-1}
# \end{equation}
#
# Hence we can use 2 auxilliary functions $h$ and $g$, to derive the subgradients.
# \begin{equation}
# h(x)=0
# \end{equation}
# \begin{equation}
# g(x)=x^2-1
# \end{equation}
#
# ![image.png](attachment:image.png)
#
# Hence we can see that the frontiers are at $x=1$ and $x=-1$, so the subgradients of $f$ come as:
# \begin{equation}
# \partial f(x) = 0, -1<x<1
# \end{equation}
# \begin{equation}
# \partial f(x)=2x, -1\geq x\ \vee\ x\geq 1
# \end{equation}
# Finally we join both of them accordingly
# \begin{equation}
# \partial f(x)=\text{conv} ({\nabla h(x),\nabla g(x)})
# \end{equation}
#
# ### 7.
# Our objective function is:
# \begin{equation}
# f(x)=x^T Q x -x^T b
# \end{equation}
# Whose gradient comes as:
# \begin{equation}
# \nabla f(x)=Q x - b
# \end{equation}
# The gradient descent method is:
# \begin{equation}
# x^{k+1}=x^k - \gamma \nabla f^k
# \end{equation}
#
# We need to show that if for the first step we reach the minimum, so $\nabla f(x^1)=0$:
# \begin{equation}
# \nabla f(x^1)=0=Q x^1 - b = Q.(x^0 - \gamma \nabla f^0) - b
# \end{equation}
# \begin{equation}
# \nabla f(x^1)=0=Q x^1 - b = Q.(x^0 - \gamma (Q.x^0-b)) - b
# \end{equation}
# So, we take the left side and solve it in terms of x^0:
# \begin{equation}
# 0 = Q.(x^0 - \gamma (Q.x^0-b)) - b
# \end{equation}
# \begin{equation}
# 0 = (Q.x^0 - \gamma Q.(Q.x^0-b)) - b = Q.x^0 - \gamma Q.x^0 - Q \gamma.b - b
# \end{equation}
# \begin{equation}
# 0=(I-\gamma.Q)(Q.x^0-b)
# \end{equation}
#
# Hence, $g^0=Q.x^0-b$ is an eigenvector of $Q$.
#
# ### 8.
# Find the minimizer of,
# \begin{equation}
# f(x, y) = x^2 + xy + 10y^2 − 22y − 5x
# \end{equation}

# %%
def f(x,y): # Function for Q.8.
    return x**2 + x*y + 10*y**2 - 22*y - 5*x;
def gradF(x,y): # its gradient
    return np.array([[2*x+y-5, x+5*y-22]]);

# %% [markdown]
# the contour and surface plots for $f(x,y)$ look like:

# %%
dx=0.01
x=np.arange(-30,30,dx) # x array for grid
y=np.arange(-30,30,dx) # y array for grid
X, Y = np.meshgrid(x, y) # grid

# Min. function
Z=f(X,Y)

# set up a figure twice as wide as it is tall
fig = plt.figure(figsize=(16,8))

# =============
# First subplot: contour
# =============
# set up the axes for the first plot
ax1 = fig.add_subplot(1, 2, 1)

# contour plot
ax1.contour(X, Y, Z)
ax1.set_title('f(x,y) - Contour plot',fontweight='bold', fontsize=15)
plt.grid()

# =============
# Second subplot: surface
# =============
# set up the axes for the second plot
ax2 = fig.add_subplot(1, 2, 2, projection='3d')
surf = ax2.plot_surface(X, Y, Z, cmap=cm.viridis,
                       linewidth=0, antialiased=False)
ax2.set_title('f(x,y) - Surface',fontweight='bold', fontsize=15)
plt.grid()

# %% [markdown]
# The gradient descent method has the following function:

# %%
def alphaF(alpha,f,x,grad):
    return f(x[0]-alpha*grad[0],x[1]-alpha*grad[1]);

def gradDescent(x0,f,gradF,alpha0,steep): # main function
    ## Initial values
    x=x0 #seed
    grad=gradF(x[0][0],x[0][1])
    alpha=alpha0
    
    # Parameters
    maxIter=50
    err=1
    tol=1e-3
    k=0

    while err > tol and k<maxIter: # iterations
        k=k+1 

        # Step 1: pick alpha
        if steep == 1: # check for scalar step-size
            # Steepest descent
            a=0 #lower bound for alpha
            b=1 #upper bound 
            alphak = optimize.minimize(alphaF,0,args=(f,x[k-1],grad[k-1]), method='Nelder-Mead').x[0]
#             alphak = optimize.bisect(alphaF,a,b,args=(f,x[k-1],grad[k-1]))
            alpha = np.append(alpha, [alphak]) # find the optimum alpha
        else:
            alpha = np.append(alpha, alpha0)
            
        # Step 3: calculate x for k+1
        x = np.append(x, [x[k-1] - alpha[k-1]*grad[k-1]],axis=0) # x^k+1
        # Step 1: Calculate gradient
        grad = np.append(grad,gradF(x[k][0],x[k][1]),axis=0)
        # Step 4: convergence
        err=np.abs(f(x[k][0],x[k][1])) #this criteria doesn't work, check tomorrow with Mile
    return x,k;

# %% [markdown]
# Just as a proof of concept we try to minimize the function for a given seed $x_0=(1,10)$

# %%
x0=np.array([[1, 10]])
alpha0=np.array([0.2])
[xRes,k]=gradDescent(x0,f,gradF,alpha0,1)
fRes=f(xRes[:,0],xRes[:,1])

plt.figure(figsize=(10,5))
plt.plot(np.linspace(0,k+1,k+1),np.array(fRes),label='$f^k$')
plt.grid()
plt.legend(fontsize=20,loc='upper right')
plt.xlabel('k - number of iterations')
# Out:
# Text(0.5, 0, 'k - number of iterations')

# %% [markdown]
# Having checked that the code works we proceed to minimize $f(x)$ with several different seeds.

# %%
# set up a figure twice as wide as it is tall
fig = plt.figure(figsize=(12,6))

# =============
# First subplot: contour
# =============
# set up the axes for the first plot

# contour plot
plt.contour(X, Y, Z)
plt.grid()

seeds=np.array([[1, 10],[10,10],[10,1]]) 
for i in range(len(seeds)):
    # pick seed
    x0=[seeds[i]]
    alpha0=np.array([0.2])
    # minimize
    [xRes,k]=gradDescent(x0,f,gradF,alpha0,1)
    fRes=f(xRes[:,0],xRes[:,1])
    
    # Plot results
    legLabel= f'$x_0=[{x0[0][0]}, {x0[0][1]}]$'
    plt.plot(xRes[:,0],xRes[:,1],'-o',label=legLabel)
    plt.legend(fontsize=15)
    plt.xlim(-30, 30)
    plt.ylim(-30, 30)

plt.show()

# %% [markdown]
# We can see how the convergence of the algorithm changes depending on the seed chosen. Additionally we also see the limitation posed by the Nealder-Mead algorithm that optimizes $\alpha^k$. Because sometimes it choses a negative scalar for the step-size, which throws away all the logic behind our method, i.e. moving against the gradient.
#
# ### 9.
# The cost function of interest is:
# \begin{equation}
# f(x)=\frac{1}{4}(x_1-1)^2+\sum_{i=2}^{n} (2.x_{i-1}^2-x_i-1)^2
# \end{equation}

# %%
def f(x)
n=np.len(x)
secondTerm=0
for i in range(n,2)
    secondTerm=secondTerm+()**2

return ((x[0]-1)**2)/4+secondTerm
